# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
df = pd.read_excel("C:/Users/37529/git/Dataset.xlsx")
df = df.set_index('Date')
decomposition = seasonal_decompose(df,model='additive',period=12)
decomposition.plot()
plt.show()

# %%
decomposition.trend
# Out:
# Date
# 2019-01-31   NaN
# 2019-02-28   NaN
# 2019-03-31   NaN
# 2019-04-30   NaN
# 2019-05-31   NaN
#               ..
# 2023-09-30   NaN
# 2023-10-31   NaN
# 2023-11-30   NaN
# 2023-12-31   NaN
# 2024-01-31   NaN
# Name: trend, Length: 61, dtype: float64

# %%
decomposition.seasonal
# Out:
# Date
# 2019-01-31   -135.555556
# 2019-02-28     66.527778
# 2019-03-31    -15.763889
# 2019-04-30      2.986111
# 2019-05-31     51.944444
#                  ...
# 2023-09-30     66.527778
# 2023-10-31    -19.930556
# 2023-11-30    -49.097222
# 2023-12-31    106.111111
# 2024-01-31   -135.555556
# Name: seasonal, Length: 61, dtype: float64

# %%
decomposition.resid
# Out:
# Date
# 2019-01-31   NaN
# 2019-02-28   NaN
# 2019-03-31   NaN
# 2019-04-30   NaN
# 2019-05-31   NaN
#               ..
# 2023-09-30   NaN
# 2023-10-31   NaN
# 2023-11-30   NaN
# 2023-12-31   NaN
# 2024-01-31   NaN
# Name: resid, Length: 61, dtype: float64
